# %%
def gen_hail(a,b):
    conv = True
    for xst in range(1,1000):    
        x = xst
        lst = []
        for i in range(1000):
            if x in lst:break
            lst += [x]
            if x % 2 == 0:
                x /= 2
            else:
                x = a*x + b
        if i == 999:
            conv = False
            break
        #print(lst)
    return conv
    

for a in range(1,10):
    for b in range(1,10):
        print(a,b,gen_hail(a,b))
# Out:
# 1 1 True
# 1 2 False
# 1 3 True
# 1 4 False
# 1 5 True
# 1 6 False
# 1 7 True
# 1 8 False
# 1 9 True
# 2 1 False
# 2 2 True
# 2 3 False
# 2 4 False
# 2 5 False
# 2 6 True
# 2 7 False
# 2 8 False
# 2 9 False
# 3 1 True
# 3 2 False
# 3 3 True
# 3 4 False
# 3 5 True
# 3 6 False
# 3 7 True
# 3 8 False
# 3 9 True
# 4 1 False
# 4 2 False
# 4 3 False
# 4 4 True
# 4 5 False
# 4 6 False
# 4 7 False
# 4 8 False
# 4 9 False
# 5 1 False
# 5 2 False
# 5 3 False
# 5 4 False
# 5 5 False
# 5 6 False
# 5 7 False
# 5 8 False
# 5 9 False
# 6 1 False
# 6 2 True
# 6 3 False
# 6 4 False
# 6 5 False
# 6 6 True
# 6 7 False
# 6 8 False
# 6 9 False
# 7 1 False
# 7 2 False
# 7 3 False
# 7 4 False
# 7 5 False
# 7 6 False
# 7 7 False
# 7 8 False
# 7 9 False
# 8 1 False
# 8 2 True
# 8 3 False
# 8 4 False
# 8 5 False
# 8 6 True
# 8 7 False
# 8 8 True
# 8 9 False
# 9 1 False
# 9 2 False
# 9 3 False
# 9 4 False
# 9 5 False
# 9 6 False
# 9 7 False
# 9 8 False
# 9 9 False

# %%
a = 3
b = 3
x = 64
lst = []
cycles = []
for i in range(1000):
    if x in lst:
        mina  = min(lst[lst.index(x):])
        if mina not in cycles:
            cycles += [mina]
        break
    lst += [x]
    if x % 2 == 0:
        x /= 2
    else:
        x = a*x + b
print(lst)
print(x)
lst.index(x)
min(lst[lst.index(x):])
# Out:
# [64, 32.0, 16.0, 8.0, 4.0, 2.0, 1.0, 6.0, 3.0, 12.0]
# 6.0
# 3.0

# %%
def gen_hail(a,b):
    conv = True
    for xst in range(1,1000):    
        x = xst
        lst = []
        for i in range(1000):
            if x in lst:break
            lst += [x]
            if x % 2 == 0:
                x /= 2
            else:
                x = a*x + b
        if i == 999:
            conv = False
            break
    #print(lst)
        return conv

for a in range(1,10):
    for b in range(1,10):
        print(a,b,gen_hail(a,b))
# Out:
# 1 1 True
# 1 2 None
# 1 3 True
# 1 4 None
# 1 5 True
# 1 6 None
# 1 7 True
# 1 8 None
# 1 9 True
# 2 1 None
# 2 2 True
# 2 3 None
# 2 4 None
# 2 5 None
# 2 6 True
# 2 7 None
# 2 8 None
# 2 9 None
# 3 1 True
# 3 2 None
# 3 3 True
# 3 4 None
# 3 5 True
# 3 6 None
# 3 7 True
# 3 8 None
# 3 9 True
# 4 1 None
# 4 2 True
# 4 3 None
# 4 4 True
# 4 5 None
# 4 6 True
# 4 7 None
# 4 8 None
# 4 9 None
# 5 1 True
# 5 2 None
# 5 3 True
# 5 4 None
# 5 5 True
# 5 6 None
# 5 7 True
# 5 8 None
# 5 9 True
# 6 1 None
# 6 2 True
# 6 3 None
# 6 4 None
# 6 5 None
# 6 6 True
# 6 7 None
# 6 8 None
# 6 9 None
# 7 1 True
# 7 2 None
# 7 3 None
# 7 4 None
# 7 5 True
# 7 6 None
# 7 7 True
# 7 8 None
# 7 9 True
# 8 1 None
# 8 2 True
# 8 3 None
# 8 4 True
# 8 5 None
# 8 6 True
# 8 7 None
# 8 8 True
# 8 9 None
# 9 1 None
# 9 2 None
# 9 3 None
# 9 4 None
# 9 5 None
# 9 6 None
# 9 7 True
# 9 8 None
# 9 9 None

# %%
r = 4
def repr(a,b):
    if len(a)==r-1
